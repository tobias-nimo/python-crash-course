# %% [markdown]
# # **Try It Yourself**
# ### *Chapter 8* - **Functions**
# ---

# %% [markdown]
# **8-1. Message**:
#
# Write a function called `display_message()` that prints one sentence telling everyone what you are learning about in this chapter. Call the function, and make sure the message displays correctly.

# %%
def display_message():
    msg = "In this chapter I´ve learned about functions. Functions are useful because ..."
    print(msg)

display_message()
# Out:
# In this chapter I´ve learned about functions. Functions are useful because ...

# %% [markdown]
# **8-2. Favorite Book**:
#
# Write a function called `favorite_book()` that accepts one
# parameter, `title`. The function should print a message, such as "One of my
# favorite books is Alice in Wonderland". Call the function, making sure to
# include a book title as an argument in the function call.

# %%
def favourite_book(title):
    msg = f"One of my favorite books is {title} !"
    print(msg)

favourite_book("Python Crash Course")
# Out:
# One of my favorite books is Python Crash Course !

# %% [markdown]
# **8-3. T-Shirt**:
#
# Write a function called `make_shirt()` that accepts a `size` and the
# `text` of a message that should be printed on the shirt. The function should print
# a sentence summarizing the size of the shirt and the message printed on it.
# Call the function once using positional arguments to make a shirt. Call the
# function a second time using keyword arguments.

# %%
def make_shirt(size, text):
    print(f"\nsize: {size}")
    print(f"Printed message: {text}")
    
make_shirt(42, "AC-DC") # positional arguments
make_shirt(size = 40, text = "Just Do It") # keyword arguments
# Out:
# size: 42
# Printed message: AC-DC
#
# size: 40
# Printed message: Just Do It

# %% [markdown]
# **8-4. Large Shirts**:
#
# Modify the `make_shirt()` function so that shirts are large
# by default with a message that reads "I love Python". Make a large shirt and a
# medium shirt with the default message, and a shirt of any size with a different
# message.

# %%
def make_shirt(size = "L", text = "I love Python"):
    print(f"\nsize: {size}")
    print(f"Printed message: {text}")
    
make_shirt()
make_shirt(size = "M")
make_shirt(size = "S", text = "I love R")
# Out:
# size: L
# Printed message: I love Python
#
# size: M
# Printed message: I love Python
#
# size: S
# Printed message: I love R

# %% [markdown]
# **8-5. Cities:**
#
# Write a function called `describe_city()` that accepts the name of
# a city and its country. The function should print a simple sentence, such as
# "Reykjavik is in Iceland". Give the parameter for the country a default value.
# Call your function for three different cities, at least one of which is not in the
# default country.

# %%
def describe_city(city, country = "Argentina"):
    msg = f"{country} is in {city}."
    print(msg)
    
describe_city("Buenos Aires")
describe_city("Córdoba")
describe_city(country = "England", city = "Manchester")
# Out:
# Argentina is in Buenos Aires.
# Argentina is in Córdoba.
# England is in Manchester.

# %% [markdown]
# **8-6. City Names:**
#
# Write a function called `city_country()` that takes in the name
# of a city and its country. The function should return a string formatted like this: "Santiago, Chile"
# Call your function with at least three city-country pairs, and print the values that are returned.

# %%
def city_country(city, country):
    str = f"{city}, {country}"
    return str

str_1 = city_country("Barcelona", "España")
str_2 = city_country("Madrid", "España")
str_3 = city_country("Paris", "Francia")

print(str_1, str_2, str_3, sep = "\n")
# Out:
# Barcelona, España
# Madrid, España
# Paris, Francia

# %% [markdown]
# **8-7. Album:**
#
# Write a function called `make_album()` that builds a dictionary
# describing a music album. The function should take in an artist name and an
# album title, and it should return a dictionary containing these two pieces of
# information. Use the function to make three dictionaries representing different
# albums. Print each return value to show that the dictionaries are storing the
# album information correctly.
#
# Use `None` to add an optional parameter to `make_album()` that allows you to
# store the number of songs on an album. If the calling line includes a value for
# the number of songs, add that value to the album’s dictionary. Make at least
# one new function call that includes the number of songs on an album.

# %%
def make_album(artist, title, n_songs = None):
    dic = {"Artist": artist.title(), "Title": title.title()}
    if n_songs:
        dic["# of Songs"] = n_songs
    return dic

dic_1 = make_album("led zeppelin", "houses of the holy", n_songs = 7)
dic_2 = make_album("deep purple", "machine head")
dic_3 = make_album("pink floyd", "the wall")

print(dic_1, dic_2, dic_3, sep = "\n")
# Out:
# {'Artist': 'Led Zeppelin', 'Title': 'Houses Of The Holy', '# of Songs': 7}
# {'Artist': 'Deep Purple', 'Title': 'Machine Head'}
# {'Artist': 'Pink Floyd', 'Title': 'The Wall'}

# %% [markdown]
# **8-8. User Albums:**
#
# Start with your program from Exercise 8-7. Write a `while`
# loop that allows users to enter an album’s artist and title. Once you have that
# information, call `make_album()` with the user’s input and print the dictionary
# that’s created. Be sure to include a quit value in the while loop.

# %%
bool_ = True

while bool_:
    artist = input("Artist name ?")
    title = input("Album title ?")
    print(f"\n{make_album(artist, title)}")
    
    answer = input("Do you wish to continue ? y/n")
    if answer == "y":
        pass
    elif answer == "n":
        bool_ = False
# Out:
# Artist name ? rolling stones
# Album title ? let it bleed
# {'Artist': 'Rolling Stones', 'Title': 'Let It Bleed'}
# Do you wish to continue ? y/n y
# Artist name ? beatles
# Album title ? let it be
# {'Artist': 'Beatles', 'Title': 'Let It Be'}
# Do you wish to continue ? y/n n

# %% [markdown]
# **8-9. Messages:**
#
# Make a list containing a series of short text messages. Pass the
# list to a function called `show_messages()`, which prints each text message.

# %%
short_msgs = ["Oh", "Babeee", "Oh my baby", "Squezeee my ..."]

def show_messages(msg_list):
    for i in msg_list:
        print(f"\n{i}")

show_messages(short_msgs)
# Out:
# Oh
#
# Babeee
#
# Oh my baby
#
# Squezeee my ...

# %% [markdown]
# **8-10. Sending Messages:**
#
# Start with a copy of your program from Exercise 8-9.
# Write a function called `send_messages()` that prints each text message and
# moves each message to a new list called `sent_messages` as it’s printed. After
# calling the function, print both of your lists to make sure the messages were
# moved correctly.

# %%
def send_messages(msg_list, sent_messages):
    for i in range(len(msg_list)):
        sending = msg_list.pop()
        sent_messages.append(sending)
        print(f"{sending}\n")

short_msgs = ["Oh", "Babeee", "Oh my baby", "Squezeee my ..."]
sent_messages = []
send_messages(short_msgs, sent_messages)

print(short_msgs, sent_messages, sep = "\n")
# Out:
# Squezeee my ...
#
# Oh my baby
#
# Babeee
#
# Oh
#
# []
# ['Squezeee my ...', 'Oh my baby', 'Babeee', 'Oh']

# %% [markdown]
# **8-11. Archived Messages:**
#
# Start with your work from Exercise 8-10. Call the
# function `send_messages()` with a copy of the list of messages. After calling the
# function, print both of your lists to show that the original list has retained its
# messages.

# %%
short_msgs = ["Oh", "Babeee", "Oh my baby", "Squezeee my ..."]
sent_messages = []

send_messages(short_msgs[:], sent_messages)

print(short_msgs, sent_messages, sep = "\n")
# Out:
# Squezeee my ...
#
# Oh my baby
#
# Babeee
#
# Oh
#
# ['Oh', 'Babeee', 'Oh my baby', 'Squezeee my ...']
# ['Squezeee my ...', 'Oh my baby', 'Babeee', 'Oh']

# %% [markdown]
# **8-12. Sandwiches:**
#
# Write a function that accepts a list of items a person wants
# on a sandwich. The function should have one parameter that collects as many
# items as the function call provides, and it should print a summary of the sandwich that’s being ordered. Call the function three times, using a different number of arguments each time.

# %%
def sandwich(*items):
    print("\nSandwich:")
    for item in items:
        print(f"\t- {item.title()}")

sandwich("cheese", "egg", "salami")
sandwich("cheese", "jam")
sandwich("milanesa")
# Out:
# Sandwich:
# 	- Cheese
# 	- Egg
# 	- Salami
#
# Sandwich:
# 	- Cheese
# 	- Jam
#
# Sandwich:
# 	- Milanesa

# %% [markdown]
# **8-13. User Profile:**
#
# Start with a copy of user_profile.py from page 149. Build a
# profile of yourself by calling `build_profile()`, using your first and last names
# and three other key-value pairs that describe you.

# %%
def build_profile(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info

build_profile(first = "Tobias", last = "Nimo",
              job = "Data Analyst", career = "Actuary", hobby = "crypto lover")
# Out:
# {'job': 'Data Analyst',
#  'career': 'Actuary',
#  'hobby': 'crypto lover',
#  'first_name': 'Tobias',
#  'last_name': 'Nimo'}

# %% [markdown]
# **8-14. Cars:**
#
# Write a function that stores information about a car in a dictionary. The function should always receive a manufacturer and a model name. It should then accept an arbitrary number of keyword arguments. Call the function with the required information and two other name-value pairs, such as a color or an optional feature. Your function should work for a call like this one:
#
# `car = make_car('subaru', 'outback', color='blue', tow_package=True)`
#
# Print the dictionary that’s returned to make sure all the information was stored correctly.

# %%
def make_car(manufacturer, model, **features):
    features["manufacturer"] = manufacturer
    features["model"] = model
    return features

car = make_car('subaru', 'outback', color='blue', tow_package=True)
print(car)
# Out:
# {'color': 'blue', 'tow_package': True, 'manufacturer': 'subaru', 'model': 'outback'}
