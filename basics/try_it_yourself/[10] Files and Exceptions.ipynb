# %% [markdown]
# # **Try It Yourself**
# ### *Chapter 10* - **Files and Exceptions**
# ---

# %% [markdown]
# **10-1. Learning Python:**
#
# Open a blank file in your text editor and write a few
# lines summarizing what you’ve learned about Python so far. Start each line
# with the phrase:
#
# line"In Python you can... "
#
# Save the file as learning_python.txt in
# the same directory as your exercises from this chapter. Write a program that
# reads the file and prints what you wrote three times. Print the contents once by
# reading in the entire file, once by looping over the file object, and once by storing the
# lines in a list and then working with them outside the with block.

# %%
file_path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/learning_python.txt"

# %%
# 1: read the entire file

with open(file_path) as file_object:
    learning_python = file_object.read()
    
print(learning_python)
# Out:
# In Python you can build ML models.
# In Python you can do exploratory data analysis.
# In Python you can automate the boring stuff.
# In Python you can solve problems with simulations.

# %%
# 2: looping over the file object

with open(file_path) as file_object:
    for line in file_object:
        print(line.strip())
# Out:
# In Python you can build ML models.
# In Python you can do exploratory data analysis.
# In Python you can automate the boring stuff.
# In Python you can solve problems with simulations.

# %%
# 3: storing the lines in a list and then working with them outside the with block

with open(file_path) as file_object:
    lines = file_object.readlines()

for line in lines:
    print(line.strip())
# Out:
# In Python you can build ML models.
# In Python you can do exploratory data analysis.
# In Python you can automate the boring stuff.
# In Python you can solve problems with simulations.

# %% [markdown]
# **10-2. Learning C++:**
#
# You can use the `replace()` method to replace any word in a
# string with a different word.
#
# Read in each line from the file you just created, learning_python.txt, and
# replace the word Python with the name of another language, such as C++. Print
# each modified line to the screen.

# %%
with open(file_path) as file_object:
    for line in file_object:
        print(line.strip().replace("Python", "C++"))
# Out:
# In C++ you can build ML models.
# In C++ you can do exploratory data analysis.
# In C++ you can automate the boring stuff.
# In C++ you can solve problems with simulations.

# %% [markdown]
# **10-3. Guest:**
#
# Write a program that prompts the user for their name. When they
# respond, write their name to a file called guest.txt.

# %%
path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/"

# %%
file_path = path + "guest.txt"

user_name = input("Type your name:")


with open(file_path, "w") as object_file:
    object_file.write(user_name)
# Out:
# Type your name: Tobias Sebastian Nimo

# %% [markdown]
# **10-4. Guest Book:**
#
# Write a while loop that prompts users for their name. When
# they enter their name, print a greeting to the screen and add a line recording
# their visit in a file called guest_book.txt. Make sure each entry appears on a
# new line in the file.

# %%
file_path = path + "guest_book.txt"
promt = "Good evening, your name sir ?"

with open(file_path, "w") as object_file:
    while True:
        guest_name = input(promt)
        guest_name += "\n"
        print(f"Welcome to the party sir. {guest_name}")
        
        object_file.write(guest_name)
        answer = input("Anyone else ?: y/n")
        if answer == "y":
            pass
        else:
            break
# Out:
# Good evening, your name sir ? Tobias
# Welcome to the party sir. Tobias
# Anyone else ?: y/n y
# Good evening, your name sir ? Sebastian
# Welcome to the party sir. Sebastian
# Anyone else ?: y/n n

# %% [markdown]
# **10-5. Programming Poll:**
#
# Write a while loop that asks people why they like
# programming. Each time someone enters a reason, add their reason to a file
# that stores all the responses.

# %%
file_path = path + "programming_poll.txt"
promt = "Why do you like programming ?"

with open(file_path, "w") as object_file:
    while True:
        reason = input(promt)
        reason += "\n"
        print(f"That´s a good one!")
        
        object_file.write(reason)
        answer = input("Any more reasons ?: y/n")
        if answer == "y":
            pass
        else:
            break
# Out:
# Why do you like programming ? It´s fun.
# That´s a good one!
# Any more reasons ?: y/n y
# Why do you like programming ? You can get a good job.
# That´s a good one!
# Any more reasons ?: y/n n

# %% [markdown]
# **10-6. Addition**:
#
# One common problem when prompting for numerical input
# occurs when people provide text instead of numbers. When you try to convert
# the input to an int, you’ll get a `ValueError`. Write a program that prompts for
# two numbers. Add them together and print the result. Catch the `ValueError` if
# either input value is not a number, and print a friendly error message. Test your
# program by entering two numbers and then by entering some text instead of a
# number.

# %%
print("Give me 2 numbers",
     "I´ll return you the sum",
     sep = "\n")

str_1 = input()
str_2 = input()

try:
    num_1 = int(str_1)
    num_2 = int(str_2)
except ValueError:
    print("Ups, input is not a number !")
else:
    result = num_1 + num_2
    print(result)
# Out:
# Give me 2 numbers
# I´ll return you the sum
#  2
#  p
# Ups, input is not a number !

# %% [markdown]
# **10-7. Addition Calculator:**
#
# Wrap your code from Exercise 10-6 in a while loop
# so the user can continue entering numbers even if they make a mistake and
# enter text instead of a number.

# %%
while True:
    print("Give me 2 numbers",
     "I´ll return the sum",
     sep = "\n")
    
    str_1 = input()
    str_2 = input()
    
    try:
        num_1 = int(str_1)
        num_2 = int(str_2)
    except ValueError:
        print("Ups, input is not a number !")
    else:
        result = num_1 + num_2
        print(result)
    
    answ = input("Continue ? y/n")
    if answ == "y":
        pass
    else:
        break
# Out:
# Give me 2 numbers
# I´ll return the sum
#  2
#  3
# 5
# Continue ? y/n y
# Give me 2 numbers
# I´ll return the sum
#  2
#  p
# Ups, input is not a number !
# Continue ? y/n n

# %%
# another option ...

print("Give me 2 numbers",
     "I´ll return the sum",
      sep = "\n")

while True:
    try:
        num_1 = int(input())
        num_2 = int(input())
    except ValueError:
        print("Ups, input is not a number !")
        continue
    else:
        result = num_1 + num_2
        print(result)
        break
# Out:
# Give me 2 numbers
# I´ll return the sum
#  2
#  p
# Ups, input is not a number !
#  0
#  10
# 10

# %% [markdown]
# **10-8. Cats and Dogs**:
#
# Make two files, cats.txt and dogs.txt. Store at least three
# names of cats in the first file and three names of dogs in the second file. Write
# a program that tries to read these files and print the contents of the file to the
# screen. Wrap your code in a try-except block to catch the `FileNotFoundError` ,
# and print a friendly message if a file is missing. Move one of the files to a different location on your system, and make sure the code in the except block
# executes properly.

# %%
path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/"
files = ["cats.txt", "dogs.txt", "birds.txt"]

for file in files:
    try:
        with open(path+file) as f:
            txt = f.read()
            print("\n"+txt.strip())
    except FileNotFoundError:
        print(f"\nError: file {file} was not found :(")
# Out:
# Michi 1
# Michi 2
# Michi 3
#
# berto
# feli
# polo
#
# Error: file birds.txt was not found :(

# %% [markdown]
# **10-9. Silent Cats and Dogs**:
#
# Modify your except block in Exercise 10-8 to fail
# silently if either file is missing.

# %%
path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/"
files = ["cats.txt", "dogs.txt", "birds.txt"]

for file in files:
    try:
        with open(path+file) as f:
            txt = f.read()
            print(txt)
    except FileNotFoundError:
        pass
# Out:
# Michi 1
# Michi 2
# Michi 3
#
# berto
# feli
# polo

# %% [markdown]
# **10-10. Common Words:**
#
# Visit Project Gutenberg (https://gutenberg.org/ )
# and find a few texts you’d like to analyze. Download the text files for these
# works, or copy the raw text from your browser into a text file on your
# computer.
#
# You can use the `count()` method to find out how many times a word or
# phrase appears in a string.
#
# Write a program that reads the files you found at Project Gutenberg and
# determines how many times the word 'the' appears in each text. This will be
# an approximation because it will also count words such as 'then' and 'there'.
# Try counting 'the ', with a space in the string, and see how much lower your
# count is.

# %%
file_path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/"
book = "blue_book.txt"

with open(file_path+book) as f:
    blue_book = f.read()

words = ["the ","the", "chess", "mate", "lasker"]    

print(f"Number of word appearences in the file {book}:")
for word in words:
    count = blue_book.lower().count(word)
    print(f"\t - `{word}` appears {count} times")
# Out:
# Number of word appearences in the file blue_book.txt:
# 	 - `the ` appears 2392 times
# 	 - `the` appears 3047 times
# 	 - `chess` appears 157 times
# 	 - `mate` appears 165 times
# 	 - `lasker` appears 13 times

# %% [markdown]
# **10-11. Favorite Number**:
#
# Write a program that prompts for the user’s favorite
# number. Use `json.dump()` to store this number in a file. Write a separate program that reads in this value and prints the message, “I know your favorite number! It’s _____.”

# %%
import json
file_path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/favorite_number.json"

# %%
# json.dump()

prompt = "What´s your favorite number"
favorite_number = input(prompt)

with open(file_path, "w") as f:
    json.dump(favorite_number, f)
# Out:
# What´s your favorite number 2.7182818284590452353602874713527

# %%
# json.load()

with open(file_path) as f:
    favorite_number = json.load(f)
    
print(f"I know your favorite number! It’s {favorite_number}")
# Out:
# I know your favorite number! It’s 2.7182818284590452353602874713527

# %% [markdown]
# **10-12. Favorite Number Remembered**:
#
# Combine the two programs from
# Exercise 10-11 into one file. If the number is already stored, report the favorite
# number to the user. If not, prompt for the user’s favorite number and store it in a
# file. Run the program twice to see that it works.

# %%
import json
file_path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/favorite_number.json"

# %%
# Load the number, if it has been stored previously. (1)
# Otherwise, prompt for the number and store it. (2)

try:                                             #(1)
    with open(file_path) as f:
        fav_num = json.load(f)
except FileNotFoundError:                        #(2)
    fav_num = input("What´s your favorite number? ")
    with open(file_path, 'w') as f:
        json.dump(fav_num, f)
        print(f"We'll remember your favorite number!")
else:
    print(f"I know your favorite number! It’s {favorite_number}")
# Out:
# I know your favorite number! It’s 2.7182818284590452353602874713527

# %% [markdown]
# **10-13. Verify User**:
#
# The final listing for remember_me.py assumes either that the
# user has already entered their username or that the program is running for the
# first time. We should modify it in case the current user is not the person who
# last used the program.
#
# Before printing a welcome back message in `greet_user()`, ask the user if
# this is the correct username. If it’s not, call `get_new_username()` to get the correct
# username.

# %%
import json
file_path = "D:/Data Science/Python/Practical Books/Python Crash Course/Jupyter Notebooks/python_work/files/username3.json"

# %%
def get_stored_username(file_path):
    """Get stored username if available."""
    try:
        with open(file_path) as f:
            username = json.load(f)
    except FileNotFoundError:
        return None
    else:
        return username

def get_new_username(file_path):
    """Prompt for a new username."""
    username = input("What is your name? ")
    with open(file_path, 'w') as f:
        json.dump(username, f)
        return username

def greet_user(file_path):
    """Greet the user by name."""
    username = get_stored_username(file_path)
    if username:
        answ = input(f"Is ´{username}´ your name ? y/n")
        if answ == "y":
            print(f"Welcome back, {username}!")
        else:
            username = get_new_username(file_path)
            print(f"We'll remember you when you come back, {username}!")
    else:
        username = get_new_username(file_path)
        print(f"We'll remember you when you come back, {username}!")

file = file_path
greet_user(file)
# Out:
# Is ´Tobias´ your name ? y/n n
# What is your name?  Sebastian
# We'll remember you when you come back, Sebastian!
